# %%
import pandas as pd

# %%
companies = pd.read_csv('method.csv')
companies
# Out:
#    Ticker    DCF method  Entreprise value method  Gorden Shapiro Method
# 0    ATVI  7.773075e+10             5.511300e+10              45.463937
# 1   CMCSA  5.041530e+11             2.963270e+11              44.534763
# 2      EA  2.639665e+10             3.188800e+10              35.005998
# 3     FOX  4.701049e+10             2.422300e+10              19.776000
# 4     OMC  3.002475e+10             1.799690e+10             164.687072
# 5       T  8.314155e+11             2.974320e+11             152.159091
# 6      VZ  4.348039e+11             3.556620e+11             461.824611
# 7     LNT  7.017243e+09             2.187300e+10             255.703125
# 8     NRG  1.000771e+11             1.671300e+10              62.374314
# 9     PNW  6.216462e+08             1.519477e+10            2163.000000
# 10     SO  1.113340e+10             1.208090e+11             289.276596
# 11    WEC  8.265790e+09             4.409010e+10            1279.163669
# ...

# %%
company = companies[companies['Ticker']=='FRT']
company
# Out:
#    Ticker    DCF method  Entreprise value method  Gorden Shapiro Method
# 32    FRT  2.330994e+10             1.318732e+10             146.642438

# %%
company['Ticker'].values
# Out:
# array(['FRT'], dtype=object)
